# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
# %matplotlib inline

# %%
df = pd.read_csv('/Users/carandu/thinkful_projects/capstone_1/master.csv')
df = df.drop('HDI for year', 1)
df.shape
#dropping null value columns to avoid errors
#df.dropna(inplace = True)
#df.head()
# Out:
# (27820, 11)

# %%
df_1995 = df[df['year'] == 1995]
df_2005 = df[df['year'] == 2005]

#df_1995.country.value_counts().head(10).plot(kind='bar')
#plt.xlabel('Country')
#plt.show()

df_by_country = df.groupby(['country']).mean()
print(df_by_country)
# Out:
#                                      year  suicides_no    population  \
# country
# Albania                       1999.227273     7.462121  2.360813e+05
# Antigua and Barbuda           1999.481481     0.033951  6.142679e+03
# Argentina                     2000.000000   221.018817  2.784907e+06
# Armenia                       2002.791946     6.392617  2.595576e+05
# Aruba                         2004.285714     0.601190  7.498077e+03
# Australia                     1999.833333   194.752778  1.506605e+06
# Austria                       2000.418848   131.081152  6.383589e+05
# Azerbaijan                    1997.625000     8.625000  5.822411e+05
# Bahamas                       2001.521739     0.336957  2.375742e+04
# Bahrain                       2002.809524     1.837302  6.648383e+04
# Barbados                      1999.240000     0.590000  2.071230e+04
# Belarus                       2001.095238   237.666667  7.832234e+05
# ...

# %%
df_by_country_2 = df.groupby('country')
#df_by_age = df.groupby('country')
#df_by_gdp = df.groupby('gdp_per_capita ($)')
#df_by_gdp_percap = df.groupby('gdp_per_capita ($)')
#df_1995.head(30)
#df_1995.groupby(df.index).apply(lambda x: np.average(x.wt, weights=x.value))

df_by_country.head(12)
# Out:
#                             year  suicides_no    population  \
# country
# Albania              1999.227273     7.462121  2.360813e+05
# Antigua and Barbuda  1999.481481     0.033951  6.142679e+03
# Argentina            2000.000000   221.018817  2.784907e+06
# Armenia              2002.791946     6.392617  2.595576e+05
# Aruba                2004.285714     0.601190  7.498077e+03
# Australia            1999.833333   194.752778  1.506605e+06
# Austria              2000.418848   131.081152  6.383589e+05
# Azerbaijan           1997.625000     8.625000  5.822411e+05
# Bahamas              2001.521739     0.336957  2.375742e+04
# Bahrain              2002.809524     1.837302  6.648383e+04
# Barbados             1999.240000     0.590000  2.071230e+04
# Belarus              2001.095238   237.666667  7.832234e+05
#
#                      suicides/100k pop  gdp_per_capita ($)
# country
# Albania                       3.502879         1859.045455
# ...

# %%
df_1995.groupby('country').apply(np.mean)
# Out:
#                                 year  suicides_no    population  \
# country
# Albania                       1995.0     7.333333  2.419500e+05
# Antigua and Barbuda           1995.0     0.000000  5.570500e+03
# Argentina                     1995.0   183.666667  2.612117e+06
# Armenia                       1995.0    10.833333  2.869333e+05
# Aruba                         1995.0     0.666667  6.131750e+03
# Australia                     1995.0   180.833333  1.397192e+06
# Austria                       1995.0   149.000000  6.230858e+05
# Azerbaijan                    1995.0     4.083333  5.504917e+05
# Bahamas                       1995.0     0.166667  2.120833e+04
# Barbados                      1995.0     1.416667  2.010000e+04
# Belarus                       1995.0   266.916667  8.061333e+05
# Belgium                       1995.0   179.583333  7.939250e+05
# Belize                        1995.0     1.166667  1.504167e+04
# ...

# %%
df['suicides_no'].mean()
# Out:
# 242.57440690150972

# %%
#df.country.value_counts().head(25).plot(kind='bar')
df.country.value_counts().head(10).plot(kind='bar')
#fig = plt.figure()
plt.figure(figsize=(20,10))
plt.show()
